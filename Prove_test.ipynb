# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Ottenere per ogni regione, insieme delle province in ordine alfabetico,  ultimo num di decessi, confermati, guariti.

df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv")

col_attivi = df["Confirmed"] - df["Recovered"]
df.insert(4, "Actives", col_attivi)

df.sort_values("Last Update").groupby('Country/Region').sum()
# Out:
#                                 Confirmed  Actives  Deaths  Recovered  \
# Country/Region
# Afghanistan                            26       25       0          1
# Albania                                55       55       1          0
# Algeria                                60       48       4         12
# Andorra                                39       38       0          1
# Antarctica                              0        0       0          0
# ...                                   ...      ...     ...        ...
# Uzbekistan                             10       10       0          0
# Venezuela                              33       33       0          0
# Vietnam                                66       50       0         16
# Winter Olympics 2022                    0        0       0          0
# occupied Palestinian territory          0        0       0          0
#
#                                 Latitude  Longitude
# Country/Region
# ...

# %%
#Ottenere per ogni regione, insieme delle province in ordine alfabetico,  ultimo num di decessi, confermati, guariti.

df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv")

order_df = df.sort_values(['Country/Region', 'Province/State']).groupby(['Country/Region', 'Province/State']).sum()
order_df.loc[['Australia', 'United Kingdom']]
# Out:
#                                              Confirmed  Deaths  Recovered  \
# Country/Region Province/State
# Australia      Australian Capital Territory          2       0          0
#                From Diamond Princess                 0       0          0
#                New South Wales                     210       4          4
#                Northern Territory                    1       0          0
#                Queensland                           78       0          8
#                South Australia                      29       0          3
#                Tasmania                              7       0          0
#                Victoria                             94       0          8
#                Western Australia                    31       1          0
# United Kingdom Cayman Islands                        1       1          0
#                Channel Islands                       0       0          0
# ...

# %%
#Ottenere i dati rGGRUPPATI PER regione, primi 10 paesi per confermati (last update, confermati, morti, ricoverati)

df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv")

ord_df =df.groupby(['Country/Region'])["Confirmed", "Recovered"].sum().sort_values(['Confirmed'], ascending = False).head(10)
ord_df



mask1 = ord_df["Recovered"].between(1000, 5000)
mask2 = ord_df["Confirmed"] >  1000
final_df = ord_df[mask1 & mask2]
#len(ord_df[mask1 & mask2])
final_df
# Out:
# C:\Users\dibellagi\Anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """
#                 Confirmed  Recovered
# Country/Region
# Italy               31506       2941
# Spain               11748       1028
# Korea, South         8320       1407

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

final_df.plot(kind = "bar", y = 'Confirmed', ylabel='Number of confirmed cases')


#df.plot(kind ='bar', x='name', y='punteggio', xlabel='name', ylabel='punteggio')
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Number of confirmed cases'>

# %%
final_df.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Country/Region'>
